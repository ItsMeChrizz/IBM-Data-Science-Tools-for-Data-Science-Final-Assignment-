# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - Identify common open-source tools used in data science
# - Convert values using basic arithmetic in Python
# - Create tables in Markdown and HTML
# - Understand Jupyter Notebook workflow basics

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | VS Code            |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
print(f"{minutes} minutes is {minutes/60:.4f} hours")
# Out:
# 200 minutes is 3.3333 hours

# %% [markdown]
# ## Author
# Christopher Sario
